# %%
from snack_race.race import SnackRace, Runner
from snack_race.dice import Dice
import numpy as np

np.random.seed(1984512358)

# %%
runners = [
        Runner('A', ),
        Runner('B', [2, 3, 3, 4, 4, 5]),
        Runner('C', ),
        Runner('D', [0, 0, 0, 10, 10, 1]),
]

# %%
race = SnackRace(runners)

# %%
race.run()

# %%
race.show()

# %%
race.get_summary_df()
